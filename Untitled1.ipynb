# %%
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
matplotlib.style.use('fivethirtyeight')
data=pd.read_csv('https://raw.githubusercontent.com/ruchisahu/dataAnalysis_cloud9/master/olympic-games/athletes.csv')

# %%
data['weight'] = data.weight.fillna(0)
data['height'] = data.height.fillna(0)
data = data[data.weight>0]
data = data[data.height>0]
males = data[data.sex == 'male']
females = data[data.sex == 'female']
males = data[data.sex == 'male']
females = data[data.sex == 'female']

# %%
legend = []
sports = ['volleyball','basketball','football']
for sport in sports:
    plt.scatter(males.height[males.sport == sport],males.weight[males.sport == sport])
    legend.append(sport)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.legend(legend, loc = 2,numpoints=3)
plt.title('height and weight  difference in sports?')
plt.xlabel('Height [m]')
plt.ylabel('Weight [kg]')
plt.show()

# %%
data.head(5)
# Out:
#             id            name nationality     sex       dob  height  weight  \
# 0  736041664.0  A Jesus Garcia         ESP    male  10/17/69    1.72    64.0
# 1  532037425.0      A Lam Shin         KOR  female   9/23/86    1.68    56.0
# 2  435962603.0     Aaron Brown         CAN    male   5/27/92    1.98    79.0
# 3  521041435.0      Aaron Cook         MDA    male    1/2/91    1.83    80.0
# 4   33922579.0      Aaron Gate         NZL    male  11/26/90    1.81    71.0
#
#        sport  gold  silver  bronze   Age
# 0  athletics   0.0     0.0     0.0  47.0
# 1    fencing   0.0     0.0     0.0  30.0
# 2  athletics   0.0     0.0     1.0  24.0
# 3  taekwondo   0.0     0.0     0.0  25.0
# 4    cycling   0.0     0.0     0.0  26.0

# %%
for i,row in enumerate(data.iterrows()):
    try:
        data.loc[i,'Age'] = 116 - float(row[1].dob[len(row[1].dob)-2:len(row[1].dob)])
    except TypeError:
        data.loc[i,'Age'] = 0
        
data['weight'] = data.weight.fillna(0)
data['height'] = data.height.fillna(0)
data = data[data.weight>0]
data = data[data.height>0]
data = data[data.Age>0]

# %%
legend = []
sports = ['volleyball','basketball','football']
for sport in sports:
    plt.plot(males.height[males.sport == sport],males.weight[males.sport == sport])
    legend.append(sport)


plt.legend(legend, loc = 2,numpoints=3)
plt.title('height and weight  difference in sports?')
plt.xlabel('Height [m]')
plt.ylabel('Weight [kg]')
plt.show()

# %%
pd.tools.plotting.scatter_matrix(data);
# Out:
# <img src="data:image/png;base64,...">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook
